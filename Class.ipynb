# %%
2+2
# Out:
# 4

# %%
2+3+9
# Out:
# 14

# %%
99-73
# Out:
# 26

# %%
20/2
# Out:
# 10.0

# %%
23.54*-1432
# Out:
# -33709.28

# %%
100/7
# Out:
# 14.285714285714286

# %%
100%7
# Out:
# 2

# %%
100 % 5
# Out:
# 0

# %%
3**3
# Out:
# 27

# %%
((2 + 5) * (17 - 3)) / (4 ** 3)
# Out:
# 1.53125

# %%
(2+5)
# Out:
# 7

# %%
(17-3)
# Out:
# 14

# %%
(4**3)
# Out:
# 64

# %%
(7*14)
# Out:
# 98

# %%
98/64
# Out:
# 1.53125

# %% [markdown]
# QUESTION

# %%
 7 + 2 * 3
# Out:
# 13

# %%
50 % 6
# Out:
# 2

# %%
2**8
# Out:
# 256

# %%
17//4
# Out:
# 4

# %%
17/4
# Out:
# 4.25

# %%
(3+2)*4
# Out:
# 20

# %%
3+2*4
# Out:
# 11

# %%
print("Hello World")
# Out:
# Hello World

# %%
First_name=
Last_name

# %%
poem= """twinkle twinkle little star 
how i wonder what you are
up above the world so high"""

# %%
print(poem)
# Out:
# twinkle twinkle little star
# how i wonder what you are
# up above the world so high

# %%
poem= """twinkle twinkle little star. \nHow i wonder what you are, \nup above the word so high"""

# %%
print(poem)
# Out:
# twinkle twinkle little star.
# How i wonder what you are,
# up above the word so high

# %%
# EXERCISE 2.2: Personal Introduction
# Create a formatted introduction using f-strings
# Include: name, city, favorite hobby

# %%
name= "Oluwunmi"
city= "Lagos"
hobby= "Eating and Reading"
print(f"My name is {name}.",f"I am from {city},",f"and my hobbies are {hobby}.")
# Out:
# My name is Oluwunmi. I am from Lagos, and my hobbies are Eating and Reading.

# %%
120%7
# Out:
# 1

# %% [markdown]
# > A grocery store sells a bag of ice for $1.25 and makes a 20% profit. If it sells 500 bags of ice, how much total profit does it make?
#
# We can list out the information provided and gradually convert the word problem into a mathematical expression that can be evaluated using Python.
#
# Cost of ice bag ($) = 1.25
#
# Profit margin = 20% = .2
#
# Profit per bag ($) = profit margin * cost of ice bag = .2 * 1.25
#
# No. of bags = 500
#
# Total profit = no. of bags * profit per bag = 500 * (.2 * 1.25)

# %%
cost_of_ice_bag= 1.25  
profit_margin= 0.2
profit_per_bag= cost_of_ice_bag * profit_margin
print(profit_per_bag)
number_of_bags= 500
total_profit= number_of_bags * profit_per_bag
print(total_profit)
# Out:
# 0.25
# 125.0

# %%
500*(0.2*1.25)
# Out:
# 125.0

# %%
my_favorite_number= 1
my_least_favorite_number= 5
a_neutral_number= 3

# %%
# Equality check * True
my_favorite_number== 1
# Out:
# True

# %%
5!=5
# Out:
# False

# %% [markdown]
# ASSIGNMENT
# 1. Write a single line of Python code that prints "Hello, World!" followed by your name on the next line.
#
# 2. Create five variables describing yourself (your_name, your_age, your_city, favorite_color, likes_python), then print each one with a descriptive label using print().
#
# 3. Explain the difference between an int, a float, a str, and a bool, giving one example variable of each. Use type() to verify your answers.
#
# 4. List three rules for naming variables in Python, and give one example each of a valid and an invalid variable name.
#
# 5. Evaluate the following expressions by hand, then check your answers in Python: 2 + 3 * 4, (2 + 3) * 4, 17 // 5, and 17 % 5.
#
# 6. Complete the Budget Calculator exercise: given food = 15000, transport = 5000, entertainment = 3000, and other = 2000, calculate weekly_total and monthly_total (weekly × 4), then print both.
#
# 7. Write a "Shopping Receipt" program that calculates the subtotal, 15% tax, and total for an item costing 250 with a quantity of 4.
#
# 8. Write a program that creates two string variables for a first and last name, concatenates them into a full_name, and prints the result.
#
# 9. Using an f-string, write a sentence that includes a person's name, age, and a calculated value (e.g., their age in 10 years).
#
# 10. Demonstrate the .upper(), .lower(), .replace(), and len() string methods on a sentence of your choice, printing the result of each.

# %% [markdown]
# SOLUTION

# %%
print("Hello World")
print("Oluwunmi Oyedeji")
# Out:
# Hello World
# Oluwunmi Oyedeji

# %%
Name= "Oluwunmi Oyedeji"
Age= 20
City= "London"
Favorite_colour= "Pink"
Likes_python= True
print("My name is",Name)
print("I am", Age,"years old")
print("I live in",City)
print("My favorite colour is",Favorite_colour)
print("I love python:",Likes_python)
# Out:
# My name is Oluwunmi Oyedeji
# I am 20 years old
# I live in London
# My favorite colour is Pink
# I love python: True

# %% [markdown]
# int= Integer which means whole number e.g 42,-10,0
# float= Floating point means decimal number e.g 3.14, -8.8, 2.0
# str= string means text e.g"hello world"
# bool= Boolean means true/false

# %%
price= 8.8
age= 42
name= "Shola"
Is_student= False

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
print(type(price))
# Out:
# <class 'float'>

# %%
print(type("name"))
# Out:
# <class 'str'>

# %%
print(type(Is_student))
# Out:
# <class 'bool'>

# %% [markdown]
# Rules of naming varaibles in python
# 1. variable name can never start with a number but can contain a number.
# e.g 1X= 10 WRONG
#      X1= 10 CORRECT
# 2. you can not start a variable name with a symbol
# e.g @X1= 10 WRONG
#     X@1= 10 CORRECT
# 3. A variable name cannot have space.
# e.g Last Name WRONG
#     Last_name CORRECT

# %%
last_name= "wunmi"

# %%
2+3*4,(2+3) * 4, 17//5 and 17%5
# Out:
# (14, 20, 2)

# %%
2+3*4
# Out:
# 14

# %%
(2+3)*4
# Out:
# 20

# %%
17//5
# Out:
# 3

# %%
17 % 5
# Out:
# 2

# %%
food = 15000
transport = 5000
entertainment = 3000
other = 2000
weekly_total= food+transport+entertainment+other
monthly_total= weekly_total*4
print("weekly_total:", weekly_total)
print("monthly_total:", monthly_total)
# Out:
# weekly_total: 25000
# monthly_total: 100000

# %%
Tax= 0.15
Price= 250
Quantity= 4
Subtotal= Price * Quantity
Tax= 0.15 * Subtotal
Total= Subtotal + Tax
print("Subtotal:", Subtotal)
print("Total:", Total)
# Out:
# Subtotal: 1000
# Total: 1150.0

# %%
First_name= "Oluwunmi"
Last_name= "Oyedeji"
print(First_name+" "+Last_name)
# Out:
# Oluwunmi Oyedeji

# %%
Name= "Owofolaju Oluwashindara"
Age= 3
print(f"My name is", Name, "and i will be 13 years old, in",Age+7, "years time.")
# Out:
# My name is Owofolaju Oluwashindara and i will be 13 years old, in 10 years time.

# %%
text= "We would like to show you a description here but the site won’t allow us"
print(len(text))
print(text.upper())
print(text.lower())
print(text.replace("description","table"))
# Out:
# 72
# WE WOULD LIKE TO SHOW YOU A DESCRIPTION HERE BUT THE SITE WON’T ALLOW US
# we would like to show you a description here but the site won’t allow us
# We would like to show you a table here but the site won’t allow us

# %%
num1=int(input("Enter first number: "))
print(num1)
num2=int(input("Enter second number: "))

print(num2)

Total= num1+num2
print("the sum is:", Total)
# Out:
# 10
# 20
# the sum is: 30

# %%
fnum=int(input("enter first number:"))
snum=int(input("enter second number:"))
print("the sum is:",fnum+snum)
# Out:
# the sum is: 30

# %% [markdown]
# # EXERCISE 1.3: Boolean practice
# # Create variables for:
# # - temperature (number)
# # - is_sunny (boolean)
# # Check if it's a nice day (temp > 20 AND is_sunny)
#
# # Write your code here:

# %%
Temperature= 10
is_sunny= False
Its_a_Nice_day=(Temperature>20) and (is_sunny)
print(Its_a_Nice_day)
# Out:
# False

# %% [markdown]
# # Ask user for age
# # Print "Can vote" if age >= 18
# # Print "Cannot vote yet" if age < 18

# %%
Age= int(input("enter your age"))
if Age >= 18:
 print("can vote") 
else:
 print("cannot vote")
# Out:
# cannot vote
